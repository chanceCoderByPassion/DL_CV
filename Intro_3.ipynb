# %% [markdown]
# <a href="https://colab.research.google.com/github/chanceCoderByPassion/DL_CV/blob/master/Intro_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
random_tensor=torch.rand(5)
print(random_tensor)
print(random_tensor.ndim)
# Out:
# tensor([0.7656, 0.0272, 0.1571, 0.2415, 0.9709])
# 1

# %%
random_tensor = torch.rand(2,5,3)
print(random_tensor)
print(random_tensor.ndim)
print(random_tensor.shape)
# Out:
# tensor([[[0.5122, 0.6620, 0.1201],
#          [0.8072, 0.4045, 0.2847],
#          [0.9640, 0.7234, 0.3611],
#          [0.1871, 0.5086, 0.2350],
#          [0.2881, 0.3793, 0.9742]],
#
#         [[0.5212, 0.1518, 0.9144],
#          [0.2339, 0.9002, 0.6089],
#          [0.4057, 0.8349, 0.0865],
#          [0.8052, 0.5239, 0.5282],
#          [0.1246, 0.3199, 0.7861]]])
# 3
# torch.Size([2, 5, 3])

# %%
torch.manual_seed(42)
random_tensor = torch.rand(5)
print(random_tensor)
# Out:
# tensor([0.8823, 0.9150, 0.3829, 0.9593, 0.3904])

# %% [markdown]
# ## generate Random Integers

# %%
#torch.randint(low,high,size) size-->Shape of tensor
random_integers = torch.randint(0,10,(5,))
print(random_integers)
# Out:
# tensor([8, 4, 0, 4, 1])

# %%
# generate random numbers from a normal distribution
# torch.normal(mean,std,size)
random_normal_nos = torch.normal(0.5,2,(5,))
print(random_normal_nos)
# Out:
# tensor([-1.9568,  1.5588,  2.9422,  0.8022, -0.1638])

# %% [markdown]
# CREATING NOISE IMAGES USING PYTORCH

# %%
import matplotlib.pyplot as plt
# h x w of image 256 x 256
uniform_noise = torch.rand((256,256))
plt.imshow(uniform_noise,cmap='grey')
plt.title("Uniform noise image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %%
# h x w x c of image 256 x 256 x  3
uniform_noise_rgb = torch.rand((256,256,3))
plt.imshow(uniform_noise_rgb.numpy())
plt.title("Uniform noise image RGB")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %%
print("Shape:",uniform_noise_rgb.shape)
print("Dimensions:",uniform_noise_rgb.ndim)
print("Min Value:",torch.min(uniform_noise_rgb))
print("Max Value:",torch.max(uniform_noise_rgb))
# Out:
# Shape: torch.Size([256, 256, 3])
# Dimensions: 3
# Min Value: tensor(1.2517e-06)
# Max Value: tensor(1.0000)
